# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#activation function
def relu(z):
    return np.maximun(0, z)

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
#first approximation
def predict(X):
    #weight vector definitions w1, w2
    w = np.array([3,-2])
    w0 = 1
    #T is the traspose matrix
    z = w0 + np.dot(X.T,w)
    yp = sigmoid(z)
    return yp

# %%
example1 = np.array([23,172.1])
example2 = np.array([22,183.5])
example3 = np.array([22,168.3])
example4 = np.array([26,183.5])

print(predict(example1))
print(predict(example2))
print(predict(example3))
print(predict(example4))

# %%
# !ls

# %%
# !pwd

# %%
cvs_file = pd.read_csv("/home/rocude/DriveE/iteso/subBodyfat2023.csv")
cvs_file.head(5)
# Out:
#    Edad  Estatura  Peso
# 0    23     172.1  70.0
# 1    22     183.5  78.6
# 2    22     168.3  69.9
# 3    26     183.5  83.8
# 4    24     181.0  83.6

# %%
cvs_file.plot()
# Out:
# <AxesSubplot:>

# %%
print("Scatter Plot:  ")
plt.scatter(cvs_file["Edad"],cvs_file["Estatura"],cvs_file["Peso"])
plt.show()
# Out:
# Scatter Plot:
